# %%
from pyaaas.aaas import AaaS
from pyaaas.models.privacy_models import KAnonymity
from pyaaas.attribute_type import AttributeType
import pandas as pd

# %%
aaas = AaaS("http://35.228.153.53:8080/") # connecting to online service

# %%
data_df = pd.read_csv("../data/dummy-dataset-260219.csv", sep=";")

# %%
data_df
# Out:
#        Dummy_tag     ID      Navn  Alder Sivilstatus  Barn  \
# 0     dummy_data  PY827     Eirik     47      Ukjent     1
# 1     dummy_data  CX244      Ella     30        Gift     2
# 2     dummy_data  ZE697   Solveig     37      Ukjent     1
# 3     dummy_data  AR215     Eirik     52       Ugift     1
# 4     dummy_data  CZ546     Heidi     37      Ukjent     3
# 5     dummy_data  XF859      Nora     30        Gift     2
# 6     dummy_data  LN430      Sara     42        Enke     2
# 7     dummy_data  UX876     Johan     39        Enke     1
# 8     dummy_data  TO107    Tobias     37        Enke     2
# 9     dummy_data  OY439      Ella     42        Gift     2
# 10    dummy_data  VQ216      Arne     41        Enke     2
# 11    dummy_data  VI298       Ole     33        Enke     3
# 12    dummy_data  QE188  Kristine     42       Skilt     0
# 13    dummy_data  UL777     Stein     36       Skilt     2
# 14    dummy_data  UB444      Anne     35       Ugift     3
# 15    dummy_data  AQ596    Tobias     51        Enke     1
# 16    dummy_data  EG195    Ingrid     50       Skilt     1
# 17    dummy_data  TZ807     Eirik     49      Ukjent     1
# 18    dummy_data  ZE853    Tobias     40        Enke     1
# 19    dummy_data  AT459       Ole     42      Ukjent     1
# 20    dummy_data  SD342      Arne     53       Skilt     3
# 21    dummy_data  GX164     Eirik     30        Gift     2
# 22    dummy_data  LR559   Andreas     44        Enke     1
# 23    dummy_data  WU728      Arne     33       Ugift     3
# 24    dummy_data  RI100      Hans     56        Enke     2
# 25    dummy_data  RF333    Ingrid     41        Gift     2
# 26    dummy_data  ZT998      Sara     37        Gift     1
# 27    dummy_data  CG525     Stine     54      Ukjent     4
# 28    dummy_data  IR748     Heidi     41       Skilt     0
# 29    dummy_data  PX220      Ella     33        Enke     1
# ...          ...    ...       ...    ...         ...   ...
# 4970  dummy_data  LU989      Nora     54        Gift    -1
# 4971  dummy_data  XM121     Eirik     38        Gift     1
# 4972  dummy_data  NU610       Ole     41        Enke     0
# 4973  dummy_data  MC377     Johan     51        Enke     2
# 4974  dummy_data  JK262     Marie     44       Skilt     2
# 4975  dummy_data  PL554     Stine     31       Skilt     3
# 4976  dummy_data  QB899     Eirik     36       Skilt     2
# 4977  dummy_data  DK920      Hans     47       Skilt     1
# 4978  dummy_data  GH133     Einar     43        Enke     3
# 4979  dummy_data  IJ786      Sara     47       Skilt     2
# 4980  dummy_data  YT416    Ingrid     42       Skilt     3
# 4981  dummy_data  ZH563     Marie     44      Ukjent     1
# 4982  dummy_data  VA886      Hans     36        Gift     2
# 4983  dummy_data  HI598     Stein     54        Gift     1
# 4984  dummy_data  ZX393   Solveig     40      Ukjent     4
# 4985  dummy_data  BM172    Tobias     42       Ugift     3
# 4986  dummy_data  AT781       Ole     36      Ukjent     5
# 4987  dummy_data  BG733     Einar     44       Skilt     2
# 4988  dummy_data  UM395     Stein     39        Enke     3
# 4989  dummy_data  BK468      Arne     39      Ukjent     0
# 4990  dummy_data  LT502      Arne     33        Gift     3
# 4991  dummy_data  KV910     Stein     33        Enke     2
# 4992  dummy_data  CS971       Ole     45        Gift     2
# 4993  dummy_data  UP209     Einar     46       Ugift     2
# 4994  dummy_data  BH352  Kristian     42      Ukjent     1
# 4995  dummy_data  AI829   Andreas     38        Enke     2
# 4996  dummy_data  MN372      Nora     42       Skilt     1
# 4997  dummy_data  IR378    Ingrid     39       Skilt     3
# 4998  dummy_data  SI932     Einar     36        Gift     1
# 4999  dummy_data  NE378      Ella     36       Skilt     3
#
#                   Innsatsgruppe Innvandrerbakgrunn          Ledighetsstatus  \
# 0     Situasjonsbestemt innsats               Togo             Delvis ledig
# 1               Varig tilpasset            Surinam  Ordinær tiltaksdeltaker
# 2              Standard innsats              Malta             Delvis ledig
# 3              Standard innsats              Norge     Andre arbeidssøkende
# 4            Spesielt tilpasset            Surinam     Andre arbeidssøkende
# 5            Spesielt tilpasset              Malta     Andre arbeidssøkende
# 6     Situasjonsbestemt innsats              Norge     Andre arbeidssøkende
# 7               Varig tilpasset              Norge               Helt ledig
# 8              Standard innsats              Norge             Delvis ledig
# 9              Standard innsats              Malta               Helt ledig
# 10             Standard innsats              Norge  Ordinær tiltaksdeltaker
# 11              Varig tilpasset              Norge               Helt ledig
# 12             Standard innsats              Norge  Ordinær tiltaksdeltaker
# 13             Standard innsats              Norge               Helt ledig
# 14             Standard innsats              Norge     Andre arbeidssøkende
# 15             Standard innsats             Neptun               Helt ledig
# 16             Standard innsats              Norge  Ordinær tiltaksdeltaker
# 17             Standard innsats            Jupiter  Ordinær tiltaksdeltaker
# 18             Standard innsats               Togo               Helt ledig
# 19             Standard innsats              Norge  Ordinær tiltaksdeltaker
# 20    Situasjonsbestemt innsats              Japan  Ordinær tiltaksdeltaker
# 21             Standard innsats             Neptun               Helt ledig
# 22           Spesielt tilpasset              Norge  Ordinær tiltaksdeltaker
# 23             Standard innsats            Surinam  Ordinær tiltaksdeltaker
# 24             Standard innsats              Norge               Helt ledig
# 25           Spesielt tilpasset               Togo             Delvis ledig
# 26             Standard innsats              Norge               Helt ledig
# 27             Standard innsats               Togo  Ordinær tiltaksdeltaker
# 28             Standard innsats              Norge             Delvis ledig
# 29              Varig tilpasset              Norge     Andre arbeidssøkende
# ...                         ...                ...                      ...
# 4970            Varig tilpasset              Norge     Andre arbeidssøkende
# 4971           Standard innsats              Norge               Helt ledig
# 4972           Standard innsats              Norge             Delvis ledig
# 4973           Standard innsats              Malta  Ordinær tiltaksdeltaker
# 4974           Standard innsats               Togo               Helt ledig
# 4975           Standard innsats              Norge  Ordinær tiltaksdeltaker
# 4976           Standard innsats              Norge  Ordinær tiltaksdeltaker
# 4977           Standard innsats              Norge               Helt ledig
# 4978  Situasjonsbestemt innsats              Norge               Helt ledig
# 4979  Situasjonsbestemt innsats              Norge               Helt ledig
# 4980  Situasjonsbestemt innsats              Norge  Ordinær tiltaksdeltaker
# 4981  Situasjonsbestemt innsats             Neptun             Delvis ledig
# 4982           Standard innsats              Malta             Delvis ledig
# 4983           Standard innsats             Neptun  Ordinær tiltaksdeltaker
# 4984           Standard innsats              Norge               Helt ledig
# 4985           Standard innsats              Malta               Helt ledig
# 4986           Standard innsats              Norge  Ordinær tiltaksdeltaker
# 4987           Standard innsats              Norge     Andre arbeidssøkende
# 4988         Spesielt tilpasset              Malta  Ordinær tiltaksdeltaker
# 4989           Standard innsats              Norge  Ordinær tiltaksdeltaker
# 4990            Varig tilpasset              Malta  Ordinær tiltaksdeltaker
# 4991           Standard innsats              Norge  Ordinær tiltaksdeltaker
# 4992           Standard innsats            Surinam               Helt ledig
# 4993           Standard innsats              Norge     Andre arbeidssøkende
# 4994            Varig tilpasset              Norge               Helt ledig
# 4995           Standard innsats              Norge     Andre arbeidssøkende
# 4996         Spesielt tilpasset              Norge               Helt ledig
# 4997           Standard innsats              Norge  Ordinær tiltaksdeltaker
# 4998         Spesielt tilpasset            Surinam  Ordinær tiltaksdeltaker
# 4999         Spesielt tilpasset              Norge               Helt ledig
#
#                    Utdanning                   Ytelse Medisinsk forhold
# 0     Høyere utd inntil 4 år            Tiltakspenger             Ingen
# 1                 Grunnskole                Dagpenger             Ingen
# 2                 Grunnskole                Dagpenger             Ingen
# 3     Høyere utd inntil 4 år               Uføretrygd             Ingen
# 4       Høyere utd over 4 år                Dagpenger             Ingen
# 5                        VGS               Uføretrygd             Ingen
# 6     Høyere utd inntil 4 år            Tiltakspenger             Ingen
# 7                        VGS            Tiltakspenger             Ingen
# 8                 Grunnskole                Dagpenger             Ingen
# 9                     Ukjent            Tiltakspenger             Ingen
# 10                Grunnskole               Sykepenger             Ingen
# 11    Høyere utd inntil 4 år                Dagpenger             Ingen
# 12                       VGS               Uføretrygd             Ingen
# 13                       VGS  Arbeidsavklaringspenger           Artrose
# 14                       VGS                Dagpenger     Hjerteflimmer
# 15                       VGS            Tiltakspenger             Ingen
# 16                Grunnskole            Tiltakspenger             Ingen
# 17    Høyere utd inntil 4 år            Tiltakspenger     Hjerteflimmer
# 18                    Ukjent                Dagpenger             Ingen
# 19                       VGS                Dagpenger             Ingen
# 20                       VGS                Dagpenger             Ingen
# 21                       VGS               Uføretrygd             Ingen
# 22      Høyere utd over 4 år                Dagpenger             Ingen
# 23                    Ukjent               Sykepenger           Artrose
# 24                       VGS            Tiltakspenger             Ingen
# 25      Høyere utd over 4 år            Tiltakspenger     Hjerteflimmer
# 26    Høyere utd inntil 4 år                Dagpenger          Diabetes
# 27                       VGS               Uføretrygd             Ingen
# 28    Høyere utd inntil 4 år  Arbeidsavklaringspenger             Ingen
# 29      Høyere utd over 4 år                Dagpenger             Ingen
# ...                      ...                      ...               ...
# 4970                     VGS                Dagpenger             Ingen
# 4971                     VGS  Arbeidsavklaringspenger             Ingen
# 4972                     VGS               Sykepenger             Ingen
# 4973                  Ukjent                Dagpenger             Ingen
# 4974    Høyere utd over 4 år            Tiltakspenger     Hjerteflimmer
# 4975  Høyere utd inntil 4 år                Dagpenger           Artrose
# 4976                     VGS                Dagpenger           Artrose
# 4977                     VGS                Dagpenger             Ingen
# 4978  Høyere utd inntil 4 år            Tiltakspenger             Ingen
# 4979  Høyere utd inntil 4 år                Dagpenger          Diabetes
# 4980                     VGS            Tiltakspenger           Artrose
# 4981    Høyere utd over 4 år               Sykepenger             Ingen
# 4982  Høyere utd inntil 4 år  Arbeidsavklaringspenger             Ingen
# 4983                     VGS               Uføretrygd             Ingen
# 4984  Høyere utd inntil 4 år               Sykepenger           Artrose
# 4985  Høyere utd inntil 4 år  Arbeidsavklaringspenger             Ingen
# 4986  Høyere utd inntil 4 år               Uføretrygd             Ingen
# 4987                     VGS                Dagpenger             Ingen
# 4988                     VGS            Tiltakspenger             Ingen
# 4989    Høyere utd over 4 år            Tiltakspenger     Hjerteflimmer
# 4990    Høyere utd over 4 år  Arbeidsavklaringspenger             Ingen
# 4991                     VGS                Dagpenger             Ingen
# 4992    Høyere utd over 4 år               Sykepenger             Ingen
# 4993  Høyere utd inntil 4 år            Tiltakspenger          Diabetes
# 4994                  Ukjent                Dagpenger             Ingen
# 4995                     VGS                Dagpenger          Diabetes
# 4996  Høyere utd inntil 4 år  Arbeidsavklaringspenger             Ingen
# 4997                     VGS                Dagpenger             Ingen
# 4998                     VGS                Dagpenger             Ingen
# 4999                     VGS            Tiltakspenger             Ingen
#
# [5000 rows x 12 columns]

# %%
aaas.set_data(data_df)

# %%
headers = data_df.columns.values.tolist()
headers
# Out:
# ['Dummy_tag',
#  'ID',
#  'Navn',
#  'Alder',
#  'Sivilstatus',
#  'Barn',
#  'Innsatsgruppe',
#  'Innvandrerbakgrunn',
#  'Ledighetsstatus',
#  'Utdanning',
#  'Ytelse',
#  'Medisinsk forhold']

# %%
attribute_types = {
 'Dummy_tag': AttributeType.INSENSITIVE,
 'ID': AttributeType.IDENTIFYING,
 'Navn': AttributeType.IDENTIFYING,
 'Alder': AttributeType.INSENSITIVE,
 'Sivilstatus': AttributeType.INSENSITIVE,
 'Barn': AttributeType.QUASIIDENTIFYING,
 'Innsatsgruppe': AttributeType.INSENSITIVE,
 'Innvandrerbakgrunn': AttributeType.QUASIIDENTIFYING,
 'Ledighetsstatus': AttributeType.QUASIIDENTIFYING,
 'Utdanning': AttributeType.INSENSITIVE,
 'Ytelse': AttributeType.QUASIIDENTIFYING,
 'Medisinsk forhold': AttributeType.IDENTIFYING
}

# %% [markdown]
# ### Set Generalization Hierarchies
# Note that if the hierarchy does not have a header row in the csv file, please set header=None in read_csv() or the first row will be interpreted as a header and ARXaaS will throw an exception for the missing hierarchy data.

# %%
ytelse_hierarchy = pd.read_csv("../hierarchies/Ytelse_hierarchy.csv", sep=";", header=None)
innsatsgruppe_hierarchy = pd.read_csv("../hierarchies/innsatsgruppe_hierarchy.csv", sep=";", header=None)
innvandrerbakgrunn_hierarchy = pd.read_csv("../hierarchies/innvandrerbakgrunn_hierarchy.csv", sep=";", header=None)
ledighetsstatus_hierarchy = pd.read_csv("../hierarchies/ledighetsstatus_hierarchy.csv", sep=";", header=None)
alder_hierarchy = pd.read_csv("../hierarchies/alder_hierarchy.csv", sep=";", header=None)
barn_hierarchy = pd.read_csv("../hierarchies/barn_hierarchy.csv", sep=";", header=None)
medisinskforhold_hierarchy = pd.read_csv("../hierarchies/medisinskforhold_hierarchy.csv", sep=";", header=None)
utdanning_hierarchy = pd.read_csv("../hierarchies/utdanning_hierarchy.csv", sep=";", header=None)

# %%
aaas.set_hierarchy('Ytelse', ytelse_hierarchy)
aaas.set_hierarchy("Innsatsgruppe", innsatsgruppe_hierarchy)
aaas.set_hierarchy("Innvandrerbakgrunn", innvandrerbakgrunn_hierarchy)
aaas.set_hierarchy("Ledighetsstatus", ledighetsstatus_hierarchy)
aaas.set_hierarchy("Barn", barn_hierarchy)
aaas.set_hierarchy("Medisinsk forhold", medisinskforhold_hierarchy)
aaas.set_hierarchy("Utdanning", utdanning_hierarchy)

# %%
ledighetsstatus_hierarchy
# Out:
#                          0             1  2
# 0     Andre arbeidssøkende  Delvis ledig  *
# 1             Delvis ledig  Delvis ledig  *
# 2               Helt ledig         ledig  *
# 3  Ordinær tiltaksdeltaker         ledig  *

# %% [markdown]
# ### Set Privacy Models

# %%
kanon = KAnonymity(4)

# %%
aaas.set_model(kanon)

# %%
aaas.set_attribute_type(attribute_types)

# %% [markdown]
# ### Run anonymization

# %%
result = aaas.anonymize()

# %%
result

# %%
result.get_result_dataframe()
# Out:
#        Dummy_tag ID Navn  Alder Sivilstatus Barn       Innsatsgruppe  \
# 0     dummy_data  *    *     47      Ukjent    *  Spesielt tilpasset
# 1     dummy_data  *    *     30        Gift    *     Varig tilpasset
# 2     dummy_data  *    *     37      Ukjent    *     Varig tilpasset
# 3     dummy_data  *    *     52       Ugift    *     Varig tilpasset
# 4     dummy_data  *    *     37      Ukjent    *  Spesielt tilpasset
# 5     dummy_data  *    *     30        Gift    *  Spesielt tilpasset
# 6     dummy_data  *    *     42        Enke    *  Spesielt tilpasset
# 7     dummy_data  *    *     39        Enke    *     Varig tilpasset
# 8     dummy_data  *    *     37        Enke    *     Varig tilpasset
# 9     dummy_data  *    *     42        Gift    *     Varig tilpasset
# 10    dummy_data  *    *     41        Enke    *     Varig tilpasset
# 11    dummy_data  *    *     33        Enke    *     Varig tilpasset
# 12    dummy_data  *    *     42       Skilt    *     Varig tilpasset
# 13    dummy_data  *    *     36       Skilt    *     Varig tilpasset
# 14    dummy_data  *    *     35       Ugift    *     Varig tilpasset
# 15    dummy_data  *    *     51        Enke    *     Varig tilpasset
# 16    dummy_data  *    *     50       Skilt    *     Varig tilpasset
# 17    dummy_data  *    *     49      Ukjent    *     Varig tilpasset
# 18    dummy_data  *    *     40        Enke    *     Varig tilpasset
# 19    dummy_data  *    *     42      Ukjent    *     Varig tilpasset
# 20    dummy_data  *    *     53       Skilt    *  Spesielt tilpasset
# 21    dummy_data  *    *     30        Gift    *     Varig tilpasset
# 22    dummy_data  *    *     44        Enke    *  Spesielt tilpasset
# 23    dummy_data  *    *     33       Ugift    *                   *
# 24    dummy_data  *    *     56        Enke    *     Varig tilpasset
# 25    dummy_data  *    *     41        Gift    *  Spesielt tilpasset
# 26    dummy_data  *    *     37        Gift    *     Varig tilpasset
# 27    dummy_data  *    *     54      Ukjent    *     Varig tilpasset
# 28    dummy_data  *    *     41       Skilt    *     Varig tilpasset
# 29    dummy_data  *    *     33        Enke    *     Varig tilpasset
# ...          ... ..  ...    ...         ...  ...                 ...
# 4970  dummy_data  *    *     54        Gift    *     Varig tilpasset
# 4971  dummy_data  *    *     38        Gift    *     Varig tilpasset
# 4972  dummy_data  *    *     41        Enke    *     Varig tilpasset
# 4973  dummy_data  *    *     51        Enke    *     Varig tilpasset
# 4974  dummy_data  *    *     44       Skilt    *     Varig tilpasset
# 4975  dummy_data  *    *     31       Skilt    *     Varig tilpasset
# 4976  dummy_data  *    *     36       Skilt    *     Varig tilpasset
# 4977  dummy_data  *    *     47       Skilt    *     Varig tilpasset
# 4978  dummy_data  *    *     43        Enke    *  Spesielt tilpasset
# 4979  dummy_data  *    *     47       Skilt    *  Spesielt tilpasset
# 4980  dummy_data  *    *     42       Skilt    *  Spesielt tilpasset
# 4981  dummy_data  *    *     44      Ukjent    *  Spesielt tilpasset
# 4982  dummy_data  *    *     36        Gift    *     Varig tilpasset
# 4983  dummy_data  *    *     54        Gift    *     Varig tilpasset
# 4984  dummy_data  *    *     40      Ukjent    *     Varig tilpasset
# 4985  dummy_data  *    *     42       Ugift    *     Varig tilpasset
# 4986  dummy_data  *    *     36      Ukjent    *     Varig tilpasset
# 4987  dummy_data  *    *     44       Skilt    *     Varig tilpasset
# 4988  dummy_data  *    *     39        Enke    *  Spesielt tilpasset
# 4989  dummy_data  *    *     39      Ukjent    *     Varig tilpasset
# 4990  dummy_data  *    *     33        Gift    *     Varig tilpasset
# 4991  dummy_data  *    *     33        Enke    *     Varig tilpasset
# 4992  dummy_data  *    *     45        Gift    *     Varig tilpasset
# 4993  dummy_data  *    *     46       Ugift    *     Varig tilpasset
# 4994  dummy_data  *    *     42      Ukjent    *     Varig tilpasset
# 4995  dummy_data  *    *     38        Enke    *     Varig tilpasset
# 4996  dummy_data  *    *     42       Skilt    *  Spesielt tilpasset
# 4997  dummy_data  *    *     39       Skilt    *     Varig tilpasset
# 4998  dummy_data  *    *     36        Gift    *  Spesielt tilpasset
# 4999  dummy_data  *    *     36       Skilt    *  Spesielt tilpasset
#
#      Innvandrerbakgrunn          Ledighetsstatus  \
# 0                     *             Delvis ledig
# 1                     *  Ordinær tiltaksdeltaker
# 2                     *             Delvis ledig
# 3                     *     Andre arbeidssøkende
# 4                     *     Andre arbeidssøkende
# 5                     *     Andre arbeidssøkende
# 6                     *     Andre arbeidssøkende
# 7                     *               Helt ledig
# 8                     *             Delvis ledig
# 9                     *               Helt ledig
# 10                    *  Ordinær tiltaksdeltaker
# 11                    *               Helt ledig
# 12                    *  Ordinær tiltaksdeltaker
# 13                    *               Helt ledig
# 14                    *     Andre arbeidssøkende
# 15                    *               Helt ledig
# 16                    *  Ordinær tiltaksdeltaker
# 17                    *  Ordinær tiltaksdeltaker
# 18                    *               Helt ledig
# 19                    *  Ordinær tiltaksdeltaker
# 20                    *  Ordinær tiltaksdeltaker
# 21                    *               Helt ledig
# 22                    *  Ordinær tiltaksdeltaker
# 23                    *                        *
# 24                    *               Helt ledig
# 25                    *             Delvis ledig
# 26                    *               Helt ledig
# 27                    *  Ordinær tiltaksdeltaker
# 28                    *             Delvis ledig
# 29                    *     Andre arbeidssøkende
# ...                 ...                      ...
# 4970                  *     Andre arbeidssøkende
# 4971                  *               Helt ledig
# 4972                  *             Delvis ledig
# 4973                  *  Ordinær tiltaksdeltaker
# 4974                  *               Helt ledig
# 4975                  *  Ordinær tiltaksdeltaker
# 4976                  *  Ordinær tiltaksdeltaker
# 4977                  *               Helt ledig
# 4978                  *               Helt ledig
# 4979                  *               Helt ledig
# 4980                  *  Ordinær tiltaksdeltaker
# 4981                  *             Delvis ledig
# 4982                  *             Delvis ledig
# 4983                  *  Ordinær tiltaksdeltaker
# 4984                  *               Helt ledig
# 4985                  *               Helt ledig
# 4986                  *  Ordinær tiltaksdeltaker
# 4987                  *     Andre arbeidssøkende
# 4988                  *  Ordinær tiltaksdeltaker
# 4989                  *  Ordinær tiltaksdeltaker
# 4990                  *  Ordinær tiltaksdeltaker
# 4991                  *  Ordinær tiltaksdeltaker
# 4992                  *               Helt ledig
# 4993                  *     Andre arbeidssøkende
# 4994                  *               Helt ledig
# 4995                  *     Andre arbeidssøkende
# 4996                  *               Helt ledig
# 4997                  *  Ordinær tiltaksdeltaker
# 4998                  *  Ordinær tiltaksdeltaker
# 4999                  *               Helt ledig
#
#                                          Utdanning                   Ytelse  \
# 0     Høyere utd inntil 4 år, Høyere utd over 4 år            Tiltakspenger
# 1                                  VGS, Grunnskole                Dagpenger
# 2                                  VGS, Grunnskole                Dagpenger
# 3     Høyere utd inntil 4 år, Høyere utd over 4 år               Uføretrygd
# 4     Høyere utd inntil 4 år, Høyere utd over 4 år                Dagpenger
# 5                                  VGS, Grunnskole               Uføretrygd
# 6     Høyere utd inntil 4 år, Høyere utd over 4 år            Tiltakspenger
# 7                                  VGS, Grunnskole            Tiltakspenger
# 8                                  VGS, Grunnskole                Dagpenger
# 9                                           Ukjent            Tiltakspenger
# 10                                 VGS, Grunnskole               Sykepenger
# 11    Høyere utd inntil 4 år, Høyere utd over 4 år                Dagpenger
# 12                                 VGS, Grunnskole               Uføretrygd
# 13                                 VGS, Grunnskole  Arbeidsavklaringspenger
# 14                                 VGS, Grunnskole                Dagpenger
# 15                                 VGS, Grunnskole            Tiltakspenger
# 16                                 VGS, Grunnskole            Tiltakspenger
# 17    Høyere utd inntil 4 år, Høyere utd over 4 år            Tiltakspenger
# 18                                          Ukjent                Dagpenger
# 19                                 VGS, Grunnskole                Dagpenger
# 20                                 VGS, Grunnskole                Dagpenger
# 21                                 VGS, Grunnskole               Uføretrygd
# 22    Høyere utd inntil 4 år, Høyere utd over 4 år                Dagpenger
# 23                                               *                        *
# 24                                 VGS, Grunnskole            Tiltakspenger
# 25    Høyere utd inntil 4 år, Høyere utd over 4 år            Tiltakspenger
# 26    Høyere utd inntil 4 år, Høyere utd over 4 år                Dagpenger
# 27                                 VGS, Grunnskole               Uføretrygd
# 28    Høyere utd inntil 4 år, Høyere utd over 4 år  Arbeidsavklaringspenger
# 29    Høyere utd inntil 4 år, Høyere utd over 4 år                Dagpenger
# ...                                            ...                      ...
# 4970                               VGS, Grunnskole                Dagpenger
# 4971                               VGS, Grunnskole  Arbeidsavklaringspenger
# 4972                               VGS, Grunnskole               Sykepenger
# 4973                                        Ukjent                Dagpenger
# 4974  Høyere utd inntil 4 år, Høyere utd over 4 år            Tiltakspenger
# 4975  Høyere utd inntil 4 år, Høyere utd over 4 år                Dagpenger
# 4976                               VGS, Grunnskole                Dagpenger
# 4977                               VGS, Grunnskole                Dagpenger
# 4978  Høyere utd inntil 4 år, Høyere utd over 4 år            Tiltakspenger
# 4979  Høyere utd inntil 4 år, Høyere utd over 4 år                Dagpenger
# 4980                               VGS, Grunnskole            Tiltakspenger
# 4981  Høyere utd inntil 4 år, Høyere utd over 4 år               Sykepenger
# 4982  Høyere utd inntil 4 år, Høyere utd over 4 år  Arbeidsavklaringspenger
# 4983                               VGS, Grunnskole               Uføretrygd
# 4984  Høyere utd inntil 4 år, Høyere utd over 4 år               Sykepenger
# 4985  Høyere utd inntil 4 år, Høyere utd over 4 år  Arbeidsavklaringspenger
# 4986  Høyere utd inntil 4 år, Høyere utd over 4 år               Uføretrygd
# 4987                               VGS, Grunnskole                Dagpenger
# 4988                               VGS, Grunnskole            Tiltakspenger
# 4989  Høyere utd inntil 4 år, Høyere utd over 4 år            Tiltakspenger
# 4990  Høyere utd inntil 4 år, Høyere utd over 4 år  Arbeidsavklaringspenger
# 4991                               VGS, Grunnskole                Dagpenger
# 4992  Høyere utd inntil 4 år, Høyere utd over 4 år               Sykepenger
# 4993  Høyere utd inntil 4 år, Høyere utd over 4 år            Tiltakspenger
# 4994                                        Ukjent                Dagpenger
# 4995                               VGS, Grunnskole                Dagpenger
# 4996  Høyere utd inntil 4 år, Høyere utd over 4 år  Arbeidsavklaringspenger
# 4997                               VGS, Grunnskole                Dagpenger
# 4998                               VGS, Grunnskole                Dagpenger
# 4999                               VGS, Grunnskole            Tiltakspenger
#
#             Medisinsk forhold
# 0     Intet medisinsk forhold
# 1     Intet medisinsk forhold
# 2     Intet medisinsk forhold
# 3     Intet medisinsk forhold
# 4     Intet medisinsk forhold
# 5     Intet medisinsk forhold
# 6     Intet medisinsk forhold
# 7     Intet medisinsk forhold
# 8     Intet medisinsk forhold
# 9     Intet medisinsk forhold
# 10    Intet medisinsk forhold
# 11    Intet medisinsk forhold
# 12    Intet medisinsk forhold
# 13          Medisinsk forhold
# 14          Medisinsk forhold
# 15    Intet medisinsk forhold
# 16    Intet medisinsk forhold
# 17          Medisinsk forhold
# 18    Intet medisinsk forhold
# 19    Intet medisinsk forhold
# 20    Intet medisinsk forhold
# 21    Intet medisinsk forhold
# 22    Intet medisinsk forhold
# 23                          *
# 24    Intet medisinsk forhold
# 25          Medisinsk forhold
# 26          Medisinsk forhold
# 27    Intet medisinsk forhold
# 28    Intet medisinsk forhold
# 29    Intet medisinsk forhold
# ...                       ...
# 4970  Intet medisinsk forhold
# 4971  Intet medisinsk forhold
# 4972  Intet medisinsk forhold
# 4973  Intet medisinsk forhold
# 4974        Medisinsk forhold
# 4975        Medisinsk forhold
# 4976        Medisinsk forhold
# 4977  Intet medisinsk forhold
# 4978  Intet medisinsk forhold
# 4979        Medisinsk forhold
# 4980        Medisinsk forhold
# 4981  Intet medisinsk forhold
# 4982  Intet medisinsk forhold
# 4983  Intet medisinsk forhold
# 4984        Medisinsk forhold
# 4985  Intet medisinsk forhold
# 4986  Intet medisinsk forhold
# 4987  Intet medisinsk forhold
# 4988  Intet medisinsk forhold
# 4989        Medisinsk forhold
# 4990  Intet medisinsk forhold
# 4991  Intet medisinsk forhold
# 4992  Intet medisinsk forhold
# 4993        Medisinsk forhold
# 4994  Intet medisinsk forhold
# 4995        Medisinsk forhold
# 4996  Intet medisinsk forhold
# 4997  Intet medisinsk forhold
# 4998  Intet medisinsk forhold
# 4999  Intet medisinsk forhold
#
# [5000 rows x 12 columns]

# %%
result.get_metrics_before()
# Out:
#                                                                               value
# metric
# measure_value                                                                   [%]
# records_affected_by_highest_risk                                               4.42
# sample_uniques                                                                 4.42
# estimated_prosecutor_risk                                                     100.0
# population_model                                                             PITMAN
# records_affected_by_lowest_risk                                   7.180000000000001
# estimated_marketer_risk                                                       15.02
# highest_prosecutor_risk                                                       100.0
# estimated_journalist_risk                                                     100.0
# lowest_risk                                                      0.6944444444444444
# average_prosecutor_risk                                                       15.02
# population_uniques                                              0.07508309185215845
# quasi_identifiers                 [Innvandrerbakgrunn, Barn, Ytelse, Ledighetsst...

# %%
result.get_metrics_after()
# Out:
#                                                                               value
# metric
# measure_value                                                                   [%]
# records_affected_by_highest_risk                                               6.02
# sample_uniques                                                                  0.0
# estimated_prosecutor_risk                                        1.7543859649122806
# population_model                                                             DANKAR
# records_affected_by_lowest_risk                                   93.97999999999999
# estimated_marketer_risk                                                        0.42
# highest_prosecutor_risk                                          1.7543859649122806
# estimated_journalist_risk                                        1.7543859649122806
# lowest_risk                                                     0.15128593040847202
# average_prosecutor_risk                                                        0.42
# population_uniques                                                              0.0
# quasi_identifiers                 [Innvandrerbakgrunn, Barn, Ytelse, Ledighetsst...
