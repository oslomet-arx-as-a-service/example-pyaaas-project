# %%
from pyaaas.aaas import AaaS
from pyaaas.models.privacy_models import KAnonymity
from pyaaas.attribute_type import AttributeType
from pyaaas.dataset import Dataset
import pandas as pd

# %%
aaas = AaaS("http://localhost:8080/") # connecting to online service

# %%
data_df = pd.read_csv("../data/dummy-dataset-260219.csv", sep=";")

# %%
data_df
# Out:
#        Dummy_tag     ID      Navn  Alder Sivilstatus  Barn  \
# 0     dummy_data  PY827     Eirik     47      Ukjent     1
# 1     dummy_data  CX244      Ella     30        Gift     2
# 2     dummy_data  ZE697   Solveig     37      Ukjent     1
# 3     dummy_data  AR215     Eirik     52       Ugift     1
# 4     dummy_data  CZ546     Heidi     37      Ukjent     3
# 5     dummy_data  XF859      Nora     30        Gift     2
# 6     dummy_data  LN430      Sara     42        Enke     2
# 7     dummy_data  UX876     Johan     39        Enke     1
# 8     dummy_data  TO107    Tobias     37        Enke     2
# 9     dummy_data  OY439      Ella     42        Gift     2
# 10    dummy_data  VQ216      Arne     41        Enke     2
# 11    dummy_data  VI298       Ole     33        Enke     3
# 12    dummy_data  QE188  Kristine     42       Skilt     0
# 13    dummy_data  UL777     Stein     36       Skilt     2
# 14    dummy_data  UB444      Anne     35       Ugift     3
# 15    dummy_data  AQ596    Tobias     51        Enke     1
# 16    dummy_data  EG195    Ingrid     50       Skilt     1
# 17    dummy_data  TZ807     Eirik     49      Ukjent     1
# 18    dummy_data  ZE853    Tobias     40        Enke     1
# 19    dummy_data  AT459       Ole     42      Ukjent     1
# 20    dummy_data  SD342      Arne     53       Skilt     3
# 21    dummy_data  GX164     Eirik     30        Gift     2
# 22    dummy_data  LR559   Andreas     44        Enke     1
# 23    dummy_data  WU728      Arne     33       Ugift     3
# 24    dummy_data  RI100      Hans     56        Enke     2
# 25    dummy_data  RF333    Ingrid     41        Gift     2
# 26    dummy_data  ZT998      Sara     37        Gift     1
# 27    dummy_data  CG525     Stine     54      Ukjent     4
# 28    dummy_data  IR748     Heidi     41       Skilt     0
# 29    dummy_data  PX220      Ella     33        Enke     1
# ...          ...    ...       ...    ...         ...   ...
# 4970  dummy_data  LU989      Nora     54        Gift    -1
# 4971  dummy_data  XM121     Eirik     38        Gift     1
# 4972  dummy_data  NU610       Ole     41        Enke     0
# 4973  dummy_data  MC377     Johan     51        Enke     2
# 4974  dummy_data  JK262     Marie     44       Skilt     2
# 4975  dummy_data  PL554     Stine     31       Skilt     3
# 4976  dummy_data  QB899     Eirik     36       Skilt     2
# 4977  dummy_data  DK920      Hans     47       Skilt     1
# 4978  dummy_data  GH133     Einar     43        Enke     3
# 4979  dummy_data  IJ786      Sara     47       Skilt     2
# 4980  dummy_data  YT416    Ingrid     42       Skilt     3
# 4981  dummy_data  ZH563     Marie     44      Ukjent     1
# 4982  dummy_data  VA886      Hans     36        Gift     2
# 4983  dummy_data  HI598     Stein     54        Gift     1
# 4984  dummy_data  ZX393   Solveig     40      Ukjent     4
# 4985  dummy_data  BM172    Tobias     42       Ugift     3
# 4986  dummy_data  AT781       Ole     36      Ukjent     5
# 4987  dummy_data  BG733     Einar     44       Skilt     2
# 4988  dummy_data  UM395     Stein     39        Enke     3
# 4989  dummy_data  BK468      Arne     39      Ukjent     0
# 4990  dummy_data  LT502      Arne     33        Gift     3
# 4991  dummy_data  KV910     Stein     33        Enke     2
# 4992  dummy_data  CS971       Ole     45        Gift     2
# 4993  dummy_data  UP209     Einar     46       Ugift     2
# 4994  dummy_data  BH352  Kristian     42      Ukjent     1
# 4995  dummy_data  AI829   Andreas     38        Enke     2
# 4996  dummy_data  MN372      Nora     42       Skilt     1
# 4997  dummy_data  IR378    Ingrid     39       Skilt     3
# 4998  dummy_data  SI932     Einar     36        Gift     1
# 4999  dummy_data  NE378      Ella     36       Skilt     3
#
#                   Innsatsgruppe Innvandrerbakgrunn          Ledighetsstatus  \
# 0     Situasjonsbestemt innsats               Togo             Delvis ledig
# 1               Varig tilpasset            Surinam  Ordinær tiltaksdeltaker
# 2              Standard innsats              Malta             Delvis ledig
# 3              Standard innsats              Norge     Andre arbeidssøkende
# 4            Spesielt tilpasset            Surinam     Andre arbeidssøkende
# 5            Spesielt tilpasset              Malta     Andre arbeidssøkende
# 6     Situasjonsbestemt innsats              Norge     Andre arbeidssøkende
# 7               Varig tilpasset              Norge               Helt ledig
# 8              Standard innsats              Norge             Delvis ledig
# 9              Standard innsats              Malta               Helt ledig
# 10             Standard innsats              Norge  Ordinær tiltaksdeltaker
# 11              Varig tilpasset              Norge               Helt ledig
# 12             Standard innsats              Norge  Ordinær tiltaksdeltaker
# 13             Standard innsats              Norge               Helt ledig
# 14             Standard innsats              Norge     Andre arbeidssøkende
# 15             Standard innsats             Neptun               Helt ledig
# 16             Standard innsats              Norge  Ordinær tiltaksdeltaker
# 17             Standard innsats            Jupiter  Ordinær tiltaksdeltaker
# 18             Standard innsats               Togo               Helt ledig
# 19             Standard innsats              Norge  Ordinær tiltaksdeltaker
# 20    Situasjonsbestemt innsats              Japan  Ordinær tiltaksdeltaker
# 21             Standard innsats             Neptun               Helt ledig
# 22           Spesielt tilpasset              Norge  Ordinær tiltaksdeltaker
# 23             Standard innsats            Surinam  Ordinær tiltaksdeltaker
# 24             Standard innsats              Norge               Helt ledig
# 25           Spesielt tilpasset               Togo             Delvis ledig
# 26             Standard innsats              Norge               Helt ledig
# 27             Standard innsats               Togo  Ordinær tiltaksdeltaker
# 28             Standard innsats              Norge             Delvis ledig
# 29              Varig tilpasset              Norge     Andre arbeidssøkende
# ...                         ...                ...                      ...
# 4970            Varig tilpasset              Norge     Andre arbeidssøkende
# 4971           Standard innsats              Norge               Helt ledig
# 4972           Standard innsats              Norge             Delvis ledig
# 4973           Standard innsats              Malta  Ordinær tiltaksdeltaker
# 4974           Standard innsats               Togo               Helt ledig
# 4975           Standard innsats              Norge  Ordinær tiltaksdeltaker
# 4976           Standard innsats              Norge  Ordinær tiltaksdeltaker
# 4977           Standard innsats              Norge               Helt ledig
# 4978  Situasjonsbestemt innsats              Norge               Helt ledig
# 4979  Situasjonsbestemt innsats              Norge               Helt ledig
# 4980  Situasjonsbestemt innsats              Norge  Ordinær tiltaksdeltaker
# 4981  Situasjonsbestemt innsats             Neptun             Delvis ledig
# 4982           Standard innsats              Malta             Delvis ledig
# 4983           Standard innsats             Neptun  Ordinær tiltaksdeltaker
# 4984           Standard innsats              Norge               Helt ledig
# 4985           Standard innsats              Malta               Helt ledig
# 4986           Standard innsats              Norge  Ordinær tiltaksdeltaker
# 4987           Standard innsats              Norge     Andre arbeidssøkende
# 4988         Spesielt tilpasset              Malta  Ordinær tiltaksdeltaker
# 4989           Standard innsats              Norge  Ordinær tiltaksdeltaker
# 4990            Varig tilpasset              Malta  Ordinær tiltaksdeltaker
# 4991           Standard innsats              Norge  Ordinær tiltaksdeltaker
# 4992           Standard innsats            Surinam               Helt ledig
# 4993           Standard innsats              Norge     Andre arbeidssøkende
# 4994            Varig tilpasset              Norge               Helt ledig
# 4995           Standard innsats              Norge     Andre arbeidssøkende
# 4996         Spesielt tilpasset              Norge               Helt ledig
# 4997           Standard innsats              Norge  Ordinær tiltaksdeltaker
# 4998         Spesielt tilpasset            Surinam  Ordinær tiltaksdeltaker
# 4999         Spesielt tilpasset              Norge               Helt ledig
#
#                    Utdanning                   Ytelse Medisinsk forhold
# 0     Høyere utd inntil 4 år            Tiltakspenger             Ingen
# 1                 Grunnskole                Dagpenger             Ingen
# 2                 Grunnskole                Dagpenger             Ingen
# 3     Høyere utd inntil 4 år               Uføretrygd             Ingen
# 4       Høyere utd over 4 år                Dagpenger             Ingen
# 5                        VGS               Uføretrygd             Ingen
# 6     Høyere utd inntil 4 år            Tiltakspenger             Ingen
# 7                        VGS            Tiltakspenger             Ingen
# 8                 Grunnskole                Dagpenger             Ingen
# 9                     Ukjent            Tiltakspenger             Ingen
# 10                Grunnskole               Sykepenger             Ingen
# 11    Høyere utd inntil 4 år                Dagpenger             Ingen
# 12                       VGS               Uføretrygd             Ingen
# 13                       VGS  Arbeidsavklaringspenger           Artrose
# 14                       VGS                Dagpenger     Hjerteflimmer
# 15                       VGS            Tiltakspenger             Ingen
# 16                Grunnskole            Tiltakspenger             Ingen
# 17    Høyere utd inntil 4 år            Tiltakspenger     Hjerteflimmer
# 18                    Ukjent                Dagpenger             Ingen
# 19                       VGS                Dagpenger             Ingen
# 20                       VGS                Dagpenger             Ingen
# 21                       VGS               Uføretrygd             Ingen
# 22      Høyere utd over 4 år                Dagpenger             Ingen
# 23                    Ukjent               Sykepenger           Artrose
# 24                       VGS            Tiltakspenger             Ingen
# 25      Høyere utd over 4 år            Tiltakspenger     Hjerteflimmer
# 26    Høyere utd inntil 4 år                Dagpenger          Diabetes
# 27                       VGS               Uføretrygd             Ingen
# 28    Høyere utd inntil 4 år  Arbeidsavklaringspenger             Ingen
# 29      Høyere utd over 4 år                Dagpenger             Ingen
# ...                      ...                      ...               ...
# 4970                     VGS                Dagpenger             Ingen
# 4971                     VGS  Arbeidsavklaringspenger             Ingen
# 4972                     VGS               Sykepenger             Ingen
# 4973                  Ukjent                Dagpenger             Ingen
# 4974    Høyere utd over 4 år            Tiltakspenger     Hjerteflimmer
# 4975  Høyere utd inntil 4 år                Dagpenger           Artrose
# 4976                     VGS                Dagpenger           Artrose
# 4977                     VGS                Dagpenger             Ingen
# 4978  Høyere utd inntil 4 år            Tiltakspenger             Ingen
# 4979  Høyere utd inntil 4 år                Dagpenger          Diabetes
# 4980                     VGS            Tiltakspenger           Artrose
# 4981    Høyere utd over 4 år               Sykepenger             Ingen
# 4982  Høyere utd inntil 4 år  Arbeidsavklaringspenger             Ingen
# 4983                     VGS               Uføretrygd             Ingen
# 4984  Høyere utd inntil 4 år               Sykepenger           Artrose
# 4985  Høyere utd inntil 4 år  Arbeidsavklaringspenger             Ingen
# 4986  Høyere utd inntil 4 år               Uføretrygd             Ingen
# 4987                     VGS                Dagpenger             Ingen
# 4988                     VGS            Tiltakspenger             Ingen
# 4989    Høyere utd over 4 år            Tiltakspenger     Hjerteflimmer
# 4990    Høyere utd over 4 år  Arbeidsavklaringspenger             Ingen
# 4991                     VGS                Dagpenger             Ingen
# 4992    Høyere utd over 4 år               Sykepenger             Ingen
# 4993  Høyere utd inntil 4 år            Tiltakspenger          Diabetes
# 4994                  Ukjent                Dagpenger             Ingen
# 4995                     VGS                Dagpenger          Diabetes
# 4996  Høyere utd inntil 4 år  Arbeidsavklaringspenger             Ingen
# 4997                     VGS                Dagpenger             Ingen
# 4998                     VGS                Dagpenger             Ingen
# 4999                     VGS            Tiltakspenger             Ingen
#
# [5000 rows x 12 columns]

# %% [markdown]
# ## Create Dataset

# %%
dataset = Dataset.from_pandas(data_df)

# %%
headers = data_df.columns.values.tolist()
headers
# Out:
# ['Dummy_tag',
#  'ID',
#  'Navn',
#  'Alder',
#  'Sivilstatus',
#  'Barn',
#  'Innsatsgruppe',
#  'Innvandrerbakgrunn',
#  'Ledighetsstatus',
#  'Utdanning',
#  'Ytelse',
#  'Medisinsk forhold']

# %%
dataset.set_attributes(['ID',
                        'Navn',
                        'Medisinsk forhold'],
                       AttributeType.IDENTIFYING)

# %%
dataset.set_attributes(['Innsatsgruppe',
                        'Innvandrerbakgrunn',
                        'Ledighetsstatus',
                           'Ytelse'],
                        AttributeType.QUASIIDENTIFYING)

dataset.set_attributes(['Dummy_tag',
                        'Alder',
                        'Sivilstatus',
                        'Barn',
                        'Utdanning'],
                       AttributeType.INSENSITIVE)

# %% [markdown]
# ### Set Generalization Hierarchies
# Note that if the hierarchy does not have a header row in the csv file, please set header=None in read_csv() or the first row will be interpreted as a header and ARXaaS will throw an exception for the missing hierarchy data.

# %%
ytelse_hierarchy = pd.read_csv("../hierarchies/Ytelse_hierarchy.csv", sep=";", header=None)
innsatsgruppe_hierarchy = pd.read_csv("../hierarchies/innsatsgruppe_hierarchy.csv", sep=";", header=None)
innvandrerbakgrunn_hierarchy = pd.read_csv("../hierarchies/innvandrerbakgrunn_hierarchy.csv", sep=";", header=None)
ledighetsstatus_hierarchy = pd.read_csv("../hierarchies/ledighetsstatus_hierarchy.csv", sep=";", header=None)

# %%
dataset.set_hierarchy('Ytelse', ytelse_hierarchy)
dataset.set_hierarchy("Innsatsgruppe", innsatsgruppe_hierarchy)
dataset.set_hierarchy("Innvandrerbakgrunn", innvandrerbakgrunn_hierarchy)
dataset.set_hierarchy("Ledighetsstatus", ledighetsstatus_hierarchy)

# %%
ledighetsstatus_hierarchy
# Out:
#                          0             1  2
# 0     Andre arbeidssøkende  Delvis ledig  *
# 1             Delvis ledig  Delvis ledig  *
# 2               Helt ledig         ledig  *
# 3  Ordinær tiltaksdeltaker         ledig  *

# %% [markdown]
# ### Create Privacy Models

# %%
kanon = KAnonymity(4)

# %% [markdown]
# ### Create Risk Profile

# %%
result = aaas.risk_profile(dataset)

# %%
result.re_identification_risk_dataframe()
# Out:
#   Journalist_attacker_success_rate Marketer_attacker_success_rate  \
# 0                            12.06                          12.06
#
#   Prosecutor_attacker_success_rate average_prosecutor_risk  \
# 0                            12.06                   12.06
#
#   estimated_journalist_risk estimated_marketer_risk estimated_prosecutor_risk  \
# 0                     100.0                   12.06                     100.0
#
#   highest_journalist_risk highest_prosecutor_risk         lowest_risk  \
# 0                   100.0                   100.0  0.4878048780487805
#
#   population_model    population_uniques  \
# 0           PITMAN  0.042243729241281044
#
#                                    quasi_identifiers  \
# 0  [Innvandrerbakgrunn, Ytelse, Innsatsgruppe, Le...
#
#   records_affected_by_highest_journalist_risk  \
# 0                          2.8000000000000003
#
#   records_affected_by_highest_prosecutor_risk records_affected_by_lowest_risk  \
# 0                          2.8000000000000003              15.620000000000001
#
#        sample_uniques
# 0  2.8000000000000003

# %%
result.re_identification_risk
# Out:
# {'Prosecutor_attacker_success_rate': '12.06',
#  'records_affected_by_highest_prosecutor_risk': '2.8000000000000003',
#  'sample_uniques': '2.8000000000000003',
#  'estimated_prosecutor_risk': '100.0',
#  'population_model': 'PITMAN',
#  'highest_journalist_risk': '100.0',
#  'records_affected_by_lowest_risk': '15.620000000000001',
#  'estimated_marketer_risk': '12.06',
#  'Journalist_attacker_success_rate': '12.06',
#  'highest_prosecutor_risk': '100.0',
#  'estimated_journalist_risk': '100.0',
#  'lowest_risk': '0.4878048780487805',
#  'Marketer_attacker_success_rate': '12.06',
#  'average_prosecutor_risk': '12.06',
#  'records_affected_by_highest_journalist_risk': '2.8000000000000003',
#  'population_uniques': '0.042243729241281044',
#  'quasi_identifiers': '[Innvandrerbakgrunn, Ytelse, Innsatsgruppe, Ledighetsstatus]'}

# %%
rdf = result.distribution_of_risk_dataframe()

# %%
rdf
# Out:
#           interval  recordsWithMaxmalRiskWithinInterval  \
# 0         ]50,100]                               1.0000
# 1        ]33.4,50]                               0.9720
# 2        ]25,33.4]                               0.9272
# 3          ]20,25]                               0.8816
# 4        ]16.7,20]                               0.8496
# 5      ]14.3,16.7]                               0.8136
# 6      ]12.5,14.3]                               0.7740
# 7        ]10,12.5]                               0.7446
# 8           ]9,10]                               0.6872
# 9            ]8,9]                               0.6512
# 10           ]7,8]                               0.6296
# 11           ]6,7]                               0.6080
# 12           ]5,6]                               0.5682
# 13           ]4,5]                               0.5046
# 14           ]3,4]                               0.4874
# 15           ]2,3]                               0.4154
# 16           ]1,2]                               0.3324
# 17         ]0.1,1]                               0.1562
# 18      ]0.01,0.1]                               0.0000
# 19    ]0.001,0.01]                               0.0000
# 20  ]0.0001,0.001]                               0.0000
# 21   ]1e-5,0.0001]                               0.0000
# 22     ]1e-6,1e-5]                               0.0000
# 23        ]0,1e-6]                               0.0000
#
#     recordsWithRiskWithinInteval
# 0                         0.0280
# 1                         0.0448
# 2                         0.0456
# 3                         0.0320
# 4                         0.0360
# 5                         0.0396
# 6                         0.0294
# 7                         0.0574
# 8                         0.0360
# 9                         0.0216
# 10                        0.0216
# 11                        0.0398
# 12                        0.0636
# 13                        0.0172
# 14                        0.0720
# 15                        0.0830
# 16                        0.1762
# 17                        0.1562
# 18                        0.0000
# 19                        0.0000
# 20                        0.0000
# 21                        0.0000
# 22                        0.0000
# 23                        0.0000

# %% [markdown]
# ## Anonymize

# %%
anon_ds = aaas.anonymize(dataset, [kanon])

# %%
anon_ds.
# Out:
# pyaaas.anonymize_result.AnonymizeResult.AnonymizationMetrics

# %%
anon_rp = aaas.risk_profile(anon_ds)

# %%
anon_rp.distributionOfRisk_to_dataframe()
# Out:
#           interval  recordsWithMaxmalRiskWithinInterval  \
# 0         ]50,100]                               1.0000
# 1        ]33.4,50]                               0.0618
# 2        ]25,33.4]                               0.0062
# 3          ]20,25]                               0.0008
# 4        ]16.7,20]                               0.0000
# 5      ]14.3,16.7]                               0.0000
# 6      ]12.5,14.3]                               0.0000
# 7        ]10,12.5]                               0.0000
# 8           ]9,10]                               0.0000
# 9            ]8,9]                               0.0000
# 10           ]7,8]                               0.0000
# 11           ]6,7]                               0.0000
# 12           ]5,6]                               0.0000
# 13           ]4,5]                               0.0000
# 14           ]3,4]                               0.0000
# 15           ]2,3]                               0.0000
# 16           ]1,2]                               0.0000
# 17         ]0.1,1]                               0.0000
# 18      ]0.01,0.1]                               0.0000
# 19    ]0.001,0.01]                               0.0000
# 20  ]0.0001,0.001]                               0.0000
# 21   ]1e-5,0.0001]                               0.0000
# 22     ]1e-6,1e-5]                               0.0000
# 23        ]0,1e-6]                               0.0000
#
#     recordsWithRiskWithinInteval
# 0                         0.9382
# 1                         0.0556
# 2                         0.0054
# 3                         0.0008
# 4                         0.0000
# 5                         0.0000
# 6                         0.0000
# 7                         0.0000
# 8                         0.0000
# 9                         0.0000
# 10                        0.0000
# 11                        0.0000
# 12                        0.0000
# 13                        0.0000
# 14                        0.0000
# 15                        0.0000
# 16                        0.0000
# 17                        0.0000
# 18                        0.0000
# 19                        0.0000
# 20                        0.0000
# 21                        0.0000
# 22                        0.0000
# 23                        0.0000

# %%
anon_rp.reIdentificationRisk_to_dataframe()
# Out:
#   Journalist_attacker_success_rate Marketer_attacker_success_rate  \
# 0                             96.8                           96.8
#
#   Prosecutor_attacker_success_rate average_prosecutor_risk  \
# 0                             96.8       96.80000000000001
#
#   estimated_journalist_risk estimated_marketer_risk estimated_prosecutor_risk  \
# 0                     100.0       96.80000000000001                     100.0
#
#   highest_journalist_risk highest_prosecutor_risk lowest_risk measure_value  \
# 0                   100.0                   100.0        25.0           [%]
#
#   population_model  population_uniques  \
# 0           PITMAN  30.589150757853673
#
#                                    quasi_identifiers  \
# 0  [Alder, Innvandrerbakgrunn, Medisinsk forhold,...
#
#   records_affected_by_highest_journalist_risk  \
# 0                           93.82000000000001
#
#   records_affected_by_highest_prosecutor_risk records_affected_by_lowest_risk  \
# 0                           93.82000000000001                            0.08
#
#       sample_uniques
# 0  93.82000000000001
